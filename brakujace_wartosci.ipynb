# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # **Brakujące wartości**
#
# **Brakujące wartości** to rekordy, które są nieobecne w zestawie danych.
#
# **Przyczyny występowania**:
# * Błąd człowieka podczas wprowadzania danych​
#
# * Ochrona prywatności (dane wrażliwe)
# * Brak odpowiedzi w ankietach
#
# Problemy techniczne przy zbieraniu danych
#
# Jest to jeden z **najczęściej występujących problemów** w analizie danych i kluczowy etap wstępnego przetwarzania (data preprocessing).

# %%
# Definicja DataFrame
df_student = pd.DataFrame({
    'imie': ['Anna', 'Piotr', 'Maria', 'Jan', 'Katarzyna', 'Tomasz', 'Magdalena', 'Paweł', 'Ewa', 'Michał'],
    'wiek': [20, 22, 21, np.nan, 23, 20, 22, np.nan, 21, 23],
    'ocena_matematyka': [4.5, np.nan, 5.0, 4.0, 3.5, 4.5, 5.0, 3.5, np.nan, 4.0],
    'ocena_fizyka': [5.0, 4.5, np.nan, 4.0, 4.5, np.nan, 5.0, 4.0, 4.5, np.nan],
    'ocena_informatyka': [4.0, 3.5, 4.5, np.nan, 5.0, 3.5, 4.5, 4.0, np.nan, 4.5],
    'miasto': ['Warszawa', 'Kraków', 'Wrocław', 'Poznań', 'Gdańsk', np.nan, 'Warszawa', 'Kraków', 'Wrocław', 'Poznań']
})

# %%
# 1. Sprawdzenie czy są brakujące wartości
print("1. Sprawdzenie brakujących wartości (True = brak):")
print(df_student.isnull())
# lub: df.isna()
print("\n" + "="*60 + "\n")
# Out:
# 1. Sprawdzenie brakujących wartości (True = brak):
#     imie   wiek  ocena_matematyka  ocena_fizyka  ocena_informatyka  miasto
# 0  False  False             False         False              False   False
# 1  False  False              True         False              False   False
# 2  False  False             False          True              False   False
# 3  False   True             False         False               True   False
# 4  False  False             False         False              False   False
# 5  False  False             False          True              False    True
# 6  False  False             False         False              False   False
# 7  False   True             False         False              False   False
# 8  False  False              True         False               True   False
# 9  False  False             False          True              False   False
#
# ============================================================

# %%
# 2. Liczba brakujących wartości w każdej kolumnie
print("2. Liczba brakujących wartości w każdej kolumnie:")
print(df_student.isna().sum())
print("\n" + "="*60 + "\n")
# Out:
# 2. Liczba brakujących wartości w każdej kolumnie:
# imie                 0
# wiek                 2
# ocena_matematyka     2
# ocena_fizyka         3
# ocena_informatyka    2
# miasto               1
# dtype: int64
#
# ============================================================

# %%
# 3. Procent brakujących wartości
print("3. Procent brakujących wartości w każdej kolumnie:")
print((df_student.isnull().sum() / len(df)) * 100)
print("\n" + "="*60 + "\n")
# Out:
# 3. Procent brakujących wartości w każdej kolumnie:
# imie                 0.000000
# wiek                 4.444444
# ocena_matematyka     4.444444
# ocena_fizyka         6.666667
# ocena_informatyka    4.444444
# miasto               2.222222
# dtype: float64
#
# ============================================================

# %%
# 4. Całkowita liczba brakujących wartości
print("4. Całkowita liczba brakujących wartości w całym DataFrame:")
print(df_student.isnull().sum().sum())
# Out:
# 4. Całkowita liczba brakujących wartości w całym DataFrame:
# 10

# %% [markdown]
# ## **Rozwiązanie kwestii brakujących danych**
#
# * **Usuwanie rekordów** zawierających brakujące wartości.
# * **Ręczne uzupełnianie** brakujących wartości.
# * Uzupełnianie **brakujących wartości wskaźnikami** tendencji centralnej, np.: średnią, medianą czy dominantą.
#   * **Średniej** używamy w przypadku cech numerycznych,
#   * **mediany** w cechach porządkowych,
#   * **dominantę** (czyli najczęściej powtarzającą się wartość) umieszczamy w cechach kategorialnych.
#
# Uzupełnianie **najbardziej prawdopodobną wartością** przy użyciu modeli uczenia maszynowego, takich jak regresja, drzewa decyzyjne czy algorytm KNN.

# %% [markdown]
# ## **Czym jest NaN i dlaczego jest wyjątkowy?**
#
# **NaN** (Not a Number) – specjalna wartość reprezentująca brakujące dane.
#
# Dane mogą zawierać różne oznaczenia braków:
# * Tekstowe: "NA", "N/A", "brak", "?", "-"
#
# * Numeryczne: 0, -999, -1​
#
# * Inne: puste stringi ""

# %%
np.nan == np.nan
# Out:
# False

# %%
np.nan is np.nan
# Out:
# True

# %% [markdown]
#  Dlatego używamy specjalnych funkcji:

# %%
pd.isna(np.nan)
# Out:
# True

# %%
pd.isnull(np.nan)
# Out:
# True

# %%
df = pd.DataFrame({
    'A': [1, np.nan, 3],# ✓ NaN - brakująca wartość ​
    'B': [4, None, 6],  # ✓ None - też brakująca ​
    'C': [7, 0, 9],     # ✗ 0 - NIE jest brakująca! ​
    'D': ['x', '', 'z'] # ✗ '' - NIE jest brakująca! ​
})

# %%
df.isnull().sum()
# Out:
# A    1
# B    1
# C    0
# D    0
# dtype: int64

# %% [markdown]
# ## **Usuwanie brakujących wartości**
#
# Usuń wiersze z DOWOLNĄ brakującą wartością (domyślnie) ​
#
# ```
# df.dropna()
# df.dropna(how='any')
# ```
#
# Usuń wiersze tylko gdy WSZYSTKIE wartości są brakujące df.dropna(how='all')
# ```
# df.dropna(how="all")
# ```
#
# Usuń kolumny z brakującymi wartościami
# ```
# df.dropna(axis=1)
# ```

# %% [markdown]
# ## **Uzupełnienie średnią lub modą​**
#
# W pandas *dataFrame* możemy uzupełnić brakujące wartości za pomocą funkcji `fillna()`.
# * Przyjmuje ona jedną wartość, która będzie wstawiana w pustych pozycjach lub zamiast wartości NaN.

# %% [markdown]
# Uzupełnia wszystkie brakujące wartości w kolumnie age średnią obliczoną z tejże kolumny
#
# ```data['age'] = data.age.fillna(data.age.mean())​```
#
# Uzupełnia wszystkie brakujące wartości w kolumnie income medianą obliczoną z tejże kolumny
#
# ```data['income']=data.income.fillna(data.income.median())```
#
# Zastępuje wszystkie brakujące wartości w kolumnie gender (kolumna kategorii) dominantą wyliczoną z tejże kolumny​
#
# ```data['gender']=data['gender'].fillna(data['gender'].mode()[0])​```

# %%
df_student
# Out:
#         imie  wiek  ocena_matematyka  ocena_fizyka  ocena_informatyka  \
# 0       Anna  20.0               4.5           5.0                4.0
# 1      Piotr  22.0               NaN           4.5                3.5
# 2      Maria  21.0               5.0           NaN                4.5
# 3        Jan   NaN               4.0           4.0                NaN
# 4  Katarzyna  23.0               3.5           4.5                5.0
# 5     Tomasz  20.0               4.5           NaN                3.5
# 6  Magdalena  22.0               5.0           5.0                4.5
# 7      Paweł   NaN               3.5           4.0                4.0
# 8        Ewa  21.0               NaN           4.5                NaN
# 9     Michał  23.0               4.0           NaN                4.5
#
#      miasto
# 0  Warszawa
# 1    Kraków
# 2   Wrocław
# 3    Poznań
# 4    Gdańsk
# 5       NaN
# 6  Warszawa
# 7    Kraków
# 8   Wrocław
# 9    Poznań

# %%
df_student["wiek"] = df_student.wiek.fillna(df_student.wiek.mean())
df_student
# Out:
#         imie  wiek  ocena_matematyka  ocena_fizyka  ocena_informatyka  \
# 0       Anna  20.0               4.5           5.0                4.0
# 1      Piotr  22.0               NaN           4.5                3.5
# 2      Maria  21.0               5.0           NaN                4.5
# 3        Jan  21.5               4.0           4.0                NaN
# 4  Katarzyna  23.0               3.5           4.5                5.0
# 5     Tomasz  20.0               4.5           NaN                3.5
# 6  Magdalena  22.0               5.0           5.0                4.5
# 7      Paweł  21.5               3.5           4.0                4.0
# 8        Ewa  21.0               NaN           4.5                NaN
# 9     Michał  23.0               4.0           NaN                4.5
#
#      miasto
# 0  Warszawa
# 1    Kraków
# 2   Wrocław
# 3    Poznań
# 4    Gdańsk
# 5       NaN
# 6  Warszawa
# 7    Kraków
# 8   Wrocław
# 9    Poznań

# %%
df_student["ocena_matematyka"] = df_student["ocena_matematyka"] .fillna(df_student["ocena_matematyka"] .mean())
df_student
# Out:
#         imie  wiek  ocena_matematyka  ocena_fizyka  ocena_informatyka  \
# 0       Anna  20.0              4.50           5.0                4.0
# 1      Piotr  22.0              4.25           4.5                3.5
# 2      Maria  21.0              5.00           NaN                4.5
# 3        Jan  21.5              4.00           4.0                NaN
# 4  Katarzyna  23.0              3.50           4.5                5.0
# 5     Tomasz  20.0              4.50           NaN                3.5
# 6  Magdalena  22.0              5.00           5.0                4.5
# 7      Paweł  21.5              3.50           4.0                4.0
# 8        Ewa  21.0              4.25           4.5                NaN
# 9     Michał  23.0              4.00           NaN                4.5
#
#      miasto
# 0  Warszawa
# 1    Kraków
# 2   Wrocław
# 3    Poznań
# 4    Gdańsk
# 5       NaN
# 6  Warszawa
# 7    Kraków
# 8   Wrocław
# 9    Poznań

# %%
df_student["miasto"] = df_student["miasto"].fillna(df_student["miasto"] .mode()[0])
df_student
# Out:
#         imie  wiek  ocena_matematyka  ocena_fizyka  ocena_informatyka  \
# 0       Anna  20.0              4.50           5.0                4.0
# 1      Piotr  22.0              4.25           4.5                3.5
# 2      Maria  21.0              5.00           NaN                4.5
# 3        Jan  21.5              4.00           4.0                NaN
# 4  Katarzyna  23.0              3.50           4.5                5.0
# 5     Tomasz  20.0              4.50           NaN                3.5
# 6  Magdalena  22.0              5.00           5.0                4.5
# 7      Paweł  21.5              3.50           4.0                4.0
# 8        Ewa  21.0              4.25           4.5                NaN
# 9     Michał  23.0              4.00           NaN                4.5
#
#      miasto
# 0  Warszawa
# 1    Kraków
# 2   Wrocław
# 3    Poznań
# 4    Gdańsk
# 5    Kraków
# 6  Warszawa
# 7    Kraków
# 8   Wrocław
# 9    Poznań

# %% [markdown]
# ## **Obsługa brakujących danych jako stringi**
#
# **Problem**
# * Dane często zawierają braki zapisane jako tekst: **"NA", "N/A", "brak", "?", "-", "brak danych"**
#
# * Pandas **nie rozpoznaje** ich automatycznie jako brakujące wartości!

# %% [markdown]
# ### **Rozwiązanie 1: Wczytywanie z pliku CSV**
#
# ```
# import pandas as pd
#
# # Definiujemy listę wartości oznaczających brak
# braki = ['NA', 'N/A', 'brak', 'brak danych', '?', '-', '']
#
# # Wczytujemy plik z parametrem na_values
# df = pd.read_csv('dane.csv', na_values=braki)
#
# ```

# %% [markdown]
# ### **Rozwiązanie 2: Zamiana po wczytaniu**

# %% [markdown]
# ```
# # Zamieniamy wybrane stringi na NaN
# df.replace(['NA', 'N/A', 'brak', 'brak danych', '?', '-'], np.nan, inplace=True)
#
# # LUB dla konkretnej kolumny
# df['kolumna'] = df['kolumna'].replace('brak', np.nan)
# ```

# %% [markdown]
# # **Zadanie**:
#
# **Dane**: Plik *nieruchomosci.csv* - 45 ofert sprzedaży mieszkań
#
# **Polecenie**
#
# * Wczytaj dane i przeanalizuj problem brakujących wartości
#
# * Zdecyduj, jak poradzić sobie z brakami w poszczególnych kolumnach
#
# * Uzasadnij swoje wybory i zaimplementuj rozwiązanie
#
# **Do przemyślenia**
#
# * Jakie typy zmiennych masz w danych?
# * Czy wszystkie braki powinny być obsłużone tak samo?
# * Jakie konsekwencje niesie każda metoda?
# * Jak to wpływa na eksploracyjną analizę danych?

# %%
df = pd.read_csv('./nieruchomosci.csv')
df.head()
# Out:
#    id    miasto  dzielnica powierzchnia  liczba_pokoi rok_budowy pietro  \
# 0   1  Warszawa    Mokotów           65             3       2015      4
# 1   2    Kraków  Krowodrza           48             2        NaN      2
# 2   3   Wrocław     Krzyki           72             3       2010   brak
# 3   4    Poznań   Grunwald           55             2       2018      3
# 4   5    Gdańsk   Wrzeszcz           80             4       1998      1
#
#    liczba_pieter parking balkon          stan  cena_m2  cena_total
# 0             10     Tak    Tak         Dobry    12500      812500
# 1              5     Nie    Tak            很好    10200      489600
# 2              4     Tak    Nie         Dobry     9800      705600
# 3              8     Tak    Tak  Bardzo dobry    11000      605000
# 4              3       ?    Tak    Do remontu     8500      680000

# %%
df.isna().sum()
# Out:
# id               0
# miasto           0
# dzielnica        0
# powierzchnia     4
# liczba_pokoi     0
# rok_budowy       4
# pietro           0
# liczba_pieter    0
# parking          0
# balkon           0
# stan             0
# cena_m2          0
# cena_total       0
# dtype: int64

# %%
missing_values = ["?", "n/a", "N/A", "na", "NA", "brak", "Brak", "--", "-", "", "None", "null", "NULL", "很好"]
df = df.replace(missing_values, pd.NA)

df.isna().sum()
# Out:
# id               0
# miasto           0
# dzielnica        0
# powierzchnia     9
# liczba_pokoi     0
# rok_budowy       7
# pietro           6
# liczba_pieter    0
# parking          5
# balkon           3
# stan             1
# cena_m2          2
# cena_total       0
# dtype: int64

# %%
df.head()
# Out:
#    id    miasto  dzielnica powierzchnia  liczba_pokoi rok_budowy pietro  \
# 0   1  Warszawa    Mokotów           65             3       2015      4
# 1   2    Kraków  Krowodrza           48             2        NaN      2
# 2   3   Wrocław     Krzyki           72             3       2010   <NA>
# 3   4    Poznań   Grunwald           55             2       2018      3
# 4   5    Gdańsk   Wrzeszcz           80             4       1998      1
#
#    liczba_pieter parking balkon          stan cena_m2  cena_total
# 0             10     Tak    Tak         Dobry   12500      812500
# 1              5     Nie    Tak          <NA>   10200      489600
# 2              4     Tak    Nie         Dobry    9800      705600
# 3              8     Tak    Tak  Bardzo dobry   11000      605000
# 4              3    <NA>    Tak    Do remontu    8500      680000

# %%
if "powierzchnia" in df.columns:
    df["powierzchnia"] = (
        df["powierzchnia"]
        .astype(str)
        .str.replace(" m2", "", regex=False)
        .str.replace(",", ".", regex=False)
    )

df["pietro"] = df["pietro"].replace([-999, "-999"], pd.NA)
df["powierzchnia"] = pd.to_numeric(df["powierzchnia"], errors="coerce")

df.loc[df["powierzchnia"] == 0, "powierzchnia"] = pd.NA

df["rok_budowy"] = pd.to_numeric(df["rok_budowy"], errors="coerce")
df.loc[df["rok_budowy"] < 1800, "rok_budowy"] = pd.NA

# %%
continuous_cols = ["powierzchnia", "cena_m2"]
discrete_cols = ["rok_budowy", "pietro"]
cat_cols = ["parking", "balkon"]
ordinal_cols = ["stan"]

# %%
for col in continuous_cols:
    if col in df.columns:
        df[col] = pd.to_numeric(df[col], errors="coerce")

for col in continuous_cols:
    if col in df.columns:
        mean_value = df[col].mean()
        df[col] = df[col].fillna(mean_value)

# %%
for col in discrete_cols:
    if col in df.columns:
        df[col] = pd.to_numeric(df[col], errors="coerce")

for col in discrete_cols:
    if col in df.columns:
        median_value = df[col].median()
        median_value_rounded = int(round(median_value))
        df[col] = df[col].fillna(median_value_rounded)
        df[col] = df[col].round()
        df[col] = df[col].astype("Int64")

# %%
for col in cat_cols:
    if col in df.columns:
        mode_value = df[col].mode()[0]
        df[col] = df[col].fillna(mode_value)

# %%
stan_order = {
    "Do remontu": 1,
    "Dobry": 2,
    "Bardzo dobry": 3
}

df["stan_code"] = df["stan"].map(stan_order)
median_code = df["stan_code"].median()
median_code_rounded = round(median_code)
df["stan_code"] = df["stan_code"].fillna(median_code_rounded)
reverse_stan_order = {v: k for k, v in stan_order.items()}
df["stan"] = df["stan_code"].map(reverse_stan_order)
df = df.drop(columns=["stan_code"])

# %%
print(df.isna().sum())
df
# Out:
# id               0
# miasto           0
# dzielnica        0
# powierzchnia     0
# liczba_pokoi     0
# rok_budowy       0
# pietro           0
# liczba_pieter    0
# parking          0
# balkon           0
# stan             0
# cena_m2          0
# cena_total       0
# dtype: int64
#     id    miasto      dzielnica  powierzchnia  liczba_pokoi  rok_budowy  \
# 0    1  Warszawa        Mokotów     65.000000             3        2015
# 1    2    Kraków      Krowodrza     48.000000             2        2012
# 2    3   Wrocław         Krzyki     72.000000             3        2010
# 3    4    Poznań       Grunwald     55.000000             2        2018
# 4    5    Gdańsk       Wrzeszcz     80.000000             4        1998
# 5    6  Warszawa    Śródmieście     64.638889             2        2020
# 6    7    Kraków       Podgórze     60.000000             3        2005
# 7    8   Wrocław   Stare Miasto     45.000000             1        2019
# 8    9    Poznań         Jeżyce     70.000000             3        2012
# 9   10    Gdańsk          Oliwa     90.000000             4        2001
# 10  11  Warszawa       Żoliborz     58.000000             2        2016
# 11  12    Kraków      Kazimierz     52.000000             2        1995
# 12  13   Wrocław      Psie Pole     68.000000             3        2012
# 13  14    Poznań         Rataje     64.638889             2        2017
# 14  15    Gdańsk        Siedlce     75.000000             3        2012
# 15  16  Warszawa          Praga     62.000000             3        2014
# 16  17    Kraków      Nowa Huta     50.000000             2        2008
# 17  18   Wrocław      Fabryczna     64.638889             4        2011
# 18  19    Poznań          Wilda     66.000000             3        1999
# 19  20    Gdańsk      Przymorze     85.000000             4        2003
# 20  21  Warszawa         Ochota     54.000000             2        2012
# 21  22    Kraków      Bronowice     64.638889             3        2013
# 22  23   Wrocław         Krzyki     70.000000             3        2009
# 23  24    Poznań        Centrum     48.000000             1        2021
# 24  25    Gdańsk    Śródmieście     95.000000             5        1997
# 25  26  Warszawa        Ursynów     60.000000             2        2015
# 26  27    Kraków        Dębniki     56.000000             2        2012
# 27  28   Wrocław   Stare Miasto     42.000000             1        2020
# 28  29    Poznań       Grunwald     64.638889             3        2007
# 29  30    Gdańsk          Zaspa     78.000000             3        2002
# 30  31  Warszawa        Wilanów     88.000000             4        2018
# 31  32    Kraków     Łagiewniki     64.638889             2        2016
# 32  33   Wrocław       Biskupin     64.000000             3        2011
# 33  34    Poznań         Sołacz     72.000000             3        1996
# 34  35    Gdańsk          Chełm     64.638889             4        2014
# 35  36  Warszawa        Bielany     58.000000             2        2012
# 36  37    Kraków         Ruczaj     51.000000             2        2019
# 37  38   Wrocław            Gaj     69.000000             3        2006
# 38  39    Poznań         Główna     46.000000             1        2022
# 39  40    Gdańsk         Morena     82.000000             4        2000
# 40  41  Warszawa       Targówek     62.000000             3        2013
# 41  42    Kraków  Mistrzejowice     64.638889             2        2017
# 42  43   Wrocław          Ołbin     55.000000             2        2012
# 43  44    Poznań       Piątkowo     64.638889             3        2010
# 44  45    Gdańsk      Suchanino     76.000000             3        2004
#
#     pietro  liczba_pieter parking balkon          stan       cena_m2  \
# 0        4             10     Tak    Tak         Dobry  12500.000000
# 1        2              5     Nie    Tak         Dobry  10200.000000
# 2        3              4     Tak    Nie         Dobry   9800.000000
# 3        3              8     Tak    Tak  Bardzo dobry  11000.000000
# 4        1              3     Tak    Tak    Do remontu   8500.000000
# 5        7             12     Tak    Tak  Bardzo dobry  15000.000000
# 6        3              6     Tak    Nie         Dobry   9500.000000
# 7        5              9     Nie    Tak  Bardzo dobry  11500.000000
# 8        2              4     Tak    Tak         Dobry  10500.000000
# 9        1              2     Tak    Tak         Dobry   9000.000000
# 10       3              7     Tak    Tak         Dobry  13000.000000
# 11       3              4     Nie    Tak    Do remontu   9000.000000
# 12       4             10     Tak    Tak         Dobry   8800.000000
# 13       6             11     Tak    Tak  Bardzo dobry  10800.000000
# 14       2              5     Tak    Tak         Dobry   8700.000000
# 15       3              8     Tak    Nie         Dobry  11500.000000
# 16       1              4     Tak    Tak         Dobry   8500.000000
# 17       3              3     Tak    Tak         Dobry   9200.000000
# 18       4              5     Nie    Tak    Do remontu   9000.000000
# 19       2              6     Tak    Tak         Dobry   8900.000000
# 20       5              9     Tak    Tak  Bardzo dobry  12800.000000
# 21       2              7     Tak    Nie         Dobry   9800.000000
# 22       3              8     Tak    Tak         Dobry   9300.000000
# 23       8             15     Tak    Tak  Bardzo dobry  10223.255814
# 24       1              3     Tak    Tak    Do remontu   8200.000000
# 25       4             11     Tak    Tak         Dobry  11800.000000
# 26       1              4     Tak    Tak         Dobry   9600.000000
# 27       6             10     Nie    Tak  Bardzo dobry  12000.000000
# 28       2              5     Tak    Tak         Dobry  10200.000000
# 29       3              9     Tak    Nie         Dobry   8400.000000
# 30       3              6     Tak    Tak  Bardzo dobry  14000.000000
# 31       4              8     Tak    Tak         Dobry   9400.000000
# 32       1              4     Tak    Tak         Dobry   9700.000000
# 33       3              2     Tak    Tak    Do remontu   9800.000000
# 34       2              7     Tak    Tak         Dobry   8800.000000
# 35       5             10     Tak    Nie         Dobry  11200.000000
# 36       3              9     Tak    Tak  Bardzo dobry  10500.000000
# 37       4              5     Nie    Tak         Dobry   8900.000000
# 38       7             12     Tak    Tak  Bardzo dobry  12500.000000
# 39       1              4     Tak    Tak         Dobry  10223.255814
# 40       2              6     Tak    Tak         Dobry  10500.000000
# 41       6             11     Tak    Tak  Bardzo dobry   9200.000000
# 42       3              7     Tak    Nie         Dobry  10000.000000
# 43       1              5     Tak    Tak         Dobry   9500.000000
# 44       2              8     Tak    Tak         Dobry   8600.000000
#
#     cena_total
# 0       812500
# 1       489600
# 2       705600
# 3       605000
# 4       680000
# 5      1200000
# 6       570000
# 7       517500
# 8       735000
# 9       810000
# 10      754000
# 11      468000
# 12      598400
# 13      648000
# 14      652500
# 15      713000
# 16      425000
# 17      644000
# 18      594000
# 19      756500
# 20      691200
# 21      588000
# 22      651000
# 23      600000
# 24      779000
# 25      708000
# 26      537600
# 27      504000
# 28      612000
# 29      655200
# 30     1232000
# 31      564000
# 32      620800
# 33      705600
# 34      704000
# 35      649600
# 36      535500
# 37      614100
# 38      575000
# 39      729400
# 40      651000
# 41      552000
# 42      550000
# 43      617500
# 44      653600

# %% [markdown]
# * Jakie typy zmiennych masz w danych?
#   * ciągłe = ["powierzchnia", "cena_m2"],
#   * dyskretne = ["rok_budowy", "pietro"],
#   * kategoryczne = ["parking", "balkon"],
#   * porządkowe = ["stan"].
# * Czy wszystkie braki powinny być obsłużone tak samo?
#   Nie, gdyż sposób obsługi konrketnych braków zależy od typu zmiennej jakiej brakuje.
# * Jakie konsekwencje niesie każda metoda?
#   * Średnia - wartości odstające mogą mocno ją zniekształcić, może powodować wystepowanie nienaturalnych wartości np. rok 1995.73,
#   * Mediana - może powodować wystepowanie nienaturalnych wartości,
#   * Moda - wzmacnia jeszcze bardziej dominującą wartość, co przy dużej ilości braków może być problematyczne.
# * Jak to wpływa na eksploracyjną analizę danych?
#   Dobra analiza, w efekcie której wybieramy odpowiednią metodę zapobiega zniekształceniu statystyk i pozwala, aby eksloracyjna analiza danych była jak najbardziej rzeczywista.
